# %%
from sample_nodes import generate_nodes_csv

# %% [markdown]
# Proporciones del CSV muy cerca de los promedios (sin meter variabilidad entre polígonos):

# %%
generate_nodes_csv(
    n_nodes=625, out_path="nodes_625.csv", seed=42,
    spacing=3.2,          # o el que uses
    nodes_per_ha=None,    # se infiere del spacing
    mode="exact_means"    # reparte por restos mayores
)
# Out:
# 'nodes_625.csv'

# %% [markdown]
# Variabilidad realista entre polígonos, pero que no se dispare y quede cerca de lo observado:

# %%
generate_nodes_csv(
    n_nodes=625, out_path="nodes_625.csv",
    spacing=3.2,
    mode="dirichlet",
    tol_l1=0.10          # p. ej. tolerancia L1 total ≤ 0.10 (opcional)
    # phi=None           # se calibra automáticamente desde tus stds
)
# Out:
# 'nodes_625.csv'

# %%
generate_nodes_csv(
    n_nodes=625, out_path="nodes_144.csv",
    spacing=3.2,       
    nodes_per_ha=None,   
    mode="dirichlet"   
)
# Out:
# 'nodes_144.csv'
