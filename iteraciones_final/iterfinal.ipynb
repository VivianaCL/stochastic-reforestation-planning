# %%
from heuristic_helper import run_batch_with_sampling

out = run_batch_with_sampling(
    N=1000,
    n_nodes=625,
    out_dir="ga_batch_625",
    sample_kwargs=dict(spacing=3.2, nodes_per_ha=None, mode="dirichlet"),  
    ga_kwargs=dict(radius=3.2, pop=40, gens=200, elite=4, tour=3, ls_rate=0.3, mut_p=0.3),
    species_csv="species_targets.csv",
    w_csv="W_matrix.csv",
)
print(out)
# Out:
# {'results_csv': 'ga_batch_625\\results.csv', 'averages_csv': 'ga_batch_625\\results_averages.csv', 'T_matrix_csv': 'ga_batch_625\\T_matrix.csv'}
